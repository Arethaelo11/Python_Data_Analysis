# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Name" : ["Daniel", "Moses", "Theo", "Marry"],
    "Age":[18, 21, 30, 74],
    "Score" : [18, 76, 54, 30]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Name  Age  Score
# 0  Daniel   18     18
# 1   Moses   21     76
# 2    Theo   30     54
# 3   Marry   74     30

# %%
df.head()
# Out:
#      Name  Age  Score
# 0  Daniel   18     18
# 1   Moses   21     76
# 2    Theo   30     54
# 3   Marry   74     30

# %%
df.tail()
# Out:
#      Name  Age  Score
# 0  Daniel   18     18
# 1   Moses   21     76
# 2    Theo   30     54
# 3   Marry   74     30

# %%
df.shape #number of rows and columns  #its a property, not a method , so no parentheses
# Out:
# (4, 3)

# %%
df.columns #column names
# Out:
# Index(['Name', 'Age', 'Score'], dtype='object')

# %%
df.info() #data types and nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Score   4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe() #statistics overview
# Out:
#              Age      Score
# count   4.000000   4.000000
# mean   35.750000  44.500000
# std    26.004807  25.787594
# min    18.000000  18.000000
# 25%    20.250000  27.000000
# 50%    25.500000  42.000000
# 75%    41.000000  59.500000
# max    74.000000  76.000000

# %%
df["Name"]
# Out:
# 0    Daniel
# 1     Moses
# 2      Theo
# 3     Marry
# Name: Name, dtype: object

# %%
df[["Name", "Score"]] #Selecting items by Columns
# Out:
#      Name  Score
# 0  Daniel     18
# 1   Moses     76
# 2    Theo     54
# 3   Marry     30

# %%
df.loc[1]   # to access rows by index
# Out:
# Name     Moses
# Age         21
# Score       76
# Name: 1, dtype: object

# %%
#Students whose Score is greater than 60
df[df["Score"] > 60]

# %%
#Multiple Conditions
df[(df["Age"] > 20) & (df["Score"] >= 50)]
# Out:
#     Name  Age  Score
# 1  Moses   21     76
# 2   Theo   30     54
