# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "name" : ["Daniel", "Theo", "Aretha"],
    "score" : [98, 60, 58]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name  score
# 0  Daniel     98
# 1    Theo     60
# 2  Aretha     58

# %% [markdown]
# ### Reading From CSV File

# %%
sales_data = pd.read_csv("dataset/sales_data.csv")

# %% [markdown]
# #### Top Five Records

# %%
sales_data.head(5)
# Out:
#    id                 product_name       price  stock  date_added
# 0   1  Gardening Gloves with Claws  $790885.80      9  12/11/2024
# 1   2                 Rice Pudding  $162401.24     18    8/3/2022
# 2   3                  Fishing Rod  $245343.84     20   16/3/2021
# 3   4        Portable Air Purifier  $438836.66      3   26/9/2025
# 4   5    Teriyaki Chicken Stir-Fry    $7092.93      3   2/12/2022

# %%
#Buttom record
sales_data.tail(5)
# Out:
#        id                  product_name       price  stock date_added
# 995   996       Cinnamon Spiced Almonds  $850968.14     15  10/7/2022
# 996   997                 Whole Chicken  $820855.46     20   6/8/2025
# 997   998  Fitness Resistance Bands Set  $149317.06     13   3/9/2023
# 998   999           Under Desk Footrest  $722419.13      3  24/9/2020
# 999  1000             Organic Green Tea  $528998.94     17   9/7/2025
